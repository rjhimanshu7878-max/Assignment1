# %%
a=10
b=20
if a>b:
    print("a is greater than b")

# %%
age=20
if age >=18:
    print("aap vote dene ke layak ho")
elif age == 18:
    print("aap vote dene ke layak ho")
elif:
     print("aap vote dene ke layak nahi ho")

# %%
age = 17

if age >= 18:
    print("You are eligible to vote.")
elif age == 18:
    print("You are not eligible to vote.")
else:
    print("You are not eligible to vote.")
# Out:
# You are eligible to vote.
