# %%
for x in student:
    print(x)

# %%
for x in range(10):
    print(x)

# %% [markdown]
# the key word is to

# %%
for x in range(10):
    if x==5:
        continue
    print(x)

# %%
student ={
    "name":"rohit",
    "class":"second year",
    "roll no":123,
    "branch":"Cse"


}

# %% [markdown]
#             while loop
#
# A while loop is used to repeatedly execute a block of code as long as a certain condition is true.

# %%
# X=1
# while condition
# code
# conditon
X=1
while X<=10:
    print(X)
    X=X+1
